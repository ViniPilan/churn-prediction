# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.axes as axes
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
ax = sns.barplot(y=['N° de clientes\nque saíram', 'N° total de\nclientes'], x=[25, 100], palette='Oranges_r')
plt.axis('off')

ax.text(x=30, y=-0.1, s='25% dos clientes totais', size=16, color=colors.to_rgb((189/255, 102/255, 26/255)), fontweight='bold')
ax.text(x=30, y=0.1, s='saem da empresa por ano', size=16, 
        color=colors.to_rgb((189/255, 102/255, 26/255)), fontweight='normal')
ax.text(x=10, y=1.6, s='Total de clientes da empresa', size=16, color=colors.to_rgb((191/255, 141/255, 98/255)), fontweight='bold')


plt.savefig('../Images/estimativa_saida.jpg', bbox_inches="tight")
plt.show()

# %%
x = ['', 'Mínimo de\nacertos', 'Máximo de\nacertos']
y = [0, 72, 82]

ax = sns.barplot(x=x, y=y, alpha=0.8, palette='Blues')
sns.lineplot(np.arange(-1,4,1), np.zeros(5) + 50, color=colors.to_rgb((100/255, 100/255, 100/255)))


ax.text(x=0.5, y=76, s='72', weight='bold', size=14, color=colors.to_rgb((90/255, 90/255, 90/255)))
ax.text(x=0.8, y=76, s='acertos', weight='normal', size=14, color=colors.to_rgb((90/255, 90/255, 90/255)))

ax.text(x=1.5, y=86, s='82', weight='bold', size=14, color=colors.to_rgb((90/255, 90/255, 90/255)))
ax.text(x=1.8, y=86, s='acertos', weight='normal', size=14, color=colors.to_rgb((90/255, 90/255, 90/255)))

ax.text(x=-1, y=46, s='Acertos pelo acaso\n(aleatoriedade)', size=10, color=colors.to_rgb((110/255, 110/255, 110/255)))

ax.text(x=-1.65, y=133, s='Usar o modelo criado será sempre mais vantajoso do que o acaso', weight='bold', size=14, color=colors.to_rgb((90/255, 90/255, 90/255)))
ax.text(x=-1.65, y=125, s='Abaixo é possível ver os acertos do modelo em comparação com a aleatoriedade.', weight='normal', size=12, color=colors.to_rgb((90/255, 90/255, 90/255)))
ax.text(x=-1.65, y=110, s='Mesmo o pior desempenho estimado do modelo já é melhor que o acaso', weight='bold', size=10, color=colors.to_rgb((90/255, 90/255, 90/255)))

#ax.get_yaxis().set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
ax.spines.left.set_color(colors.to_rgb((50/255, 50/255, 50/255)))
ax.spines.bottom.set_color(colors.to_rgb((50/255, 50/255, 50/255)))


plt.yticks(ticks=np.arange(0, 110, 50), labels=['0%', '50%', '100%'], color=colors.to_rgb((50/255, 50/255, 50/255)))
plt.xticks(ticks=[1,2], labels=['Taxa mínima\ndo modelo', 'Taxa máxima\ndo modelo'], color=colors.to_rgb((50/255, 50/255, 50/255)))

plt.savefig('../Images/modelo_e_acaso_comp.jpg', bbox_inches="tight")
plt.show()
